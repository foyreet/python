# %%
import pandas as pd
import seaborn as sns

# %%
names = 'Name1 Surname1, Name2 Surname2'

# %%
names_list = names.split(', ')

# %%
names_list
# Out:
# ['Name1 Surname1', 'Name2 Surname2']

# %%
def read_n_agg(path):
    data = pd.read_csv(path, sep =';')
    mean_inc = data.groupby('company').agg({'income':'mean'})
    return mean_inc

# %%
taxi = pd.read_csv('taxi_peru.csv', sep=';', parse_dates=['start_at', 'end_at', 'arrived_at'])

# %%
taxi.head()
# Out:
#                          journey_id                           user_id  \
# 0  23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1  dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2  dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3  dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4  85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
#
#                           driver_id                           taxi_id  \
# 0  583949a89a9ee17d19e3ca4f137b6b4c  b12f4f09c783e29fe0d0ea624530db56
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4  d665fb9f75ef5d9cd0fd89479380ba78  0accdd3aa5a322f4129fa20b53278c69
#
#         icon start_type            start_at     start_lat     start_lon  \
# ...

# %%
taxi.dtypes
# Out:
# journey_id                  object
# user_id                     object
# driver_id                   object
# taxi_id                     object
# icon                        object
# start_type                  object
# start_at            datetime64[ns]
# start_lat                   object
# start_lon                   object
# end_at              datetime64[ns]
# end_lat                     object
# end_lon                     object
# end_state                   object
# driver_start_lat            object
# driver_start_lon            object
# arrived_at          datetime64[ns]
# source                      object
# driver_score               float64
# rider_score                float64
# dtype: object

# %%
taxi
# Out:
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1      dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2      dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3      dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
# 23110  b7dea45c3cc92b9efd5a4905e69ff9bf  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id                           taxi_id  \
# ...

# %%
count_source = taxi.groupby('source').agg({'source':'count'})

# %%
all_sum_source = taxi.agg({'source':'count'})

# %%
all_sum_source
# Out:
# source    22988
# dtype: int64

# %%
count_source
# Out:
#          source
# source
# Android    4909
# Wap         136
# iPad        571
# iPhone     9741
# web        7631

# %%
9741 / 22988
# Out:
# 0.42374282234209154

# %%
sns.countplot(data=taxi, x='icon')
# Out:
# <Axes: xlabel='icon', ylabel='count'>

# %%
sns.countplot(data = taxi, x = 'source', hue = 'end_state')
# Out:
# <Axes: xlabel='source', ylabel='count'>

# %%
frequency = taxi.driver_score.value_counts()

# %%
sum_driver_score = taxi.driver_score.sum()

# %%
percent = frequency / sum_driver_score

# %%
percent.mul(100).round(2)
# Out:
# driver_score
# 5.0    14.95
# 4.0     5.56
# 0.0     3.64
# 3.0     0.75
# 1.0     0.31
# 2.0     0.21
# Name: count, dtype: float64

# %%
percent.reset_index()
# Out:
#    driver_score     count
# 0           5.0  0.149518
# 1           4.0  0.055633
# 2           0.0  0.036358
# 3           3.0  0.007544
# 4           1.0  0.003124
# 5           2.0  0.002060

# %%
percent = pd.DataFrame(percent)

# %%
percent = percent.rename(columns={'count':'percentage'})

# %%
percent
# Out:
#               percentage
# driver_score
# 5.0             0.149518
# 4.0             0.055633
# 0.0             0.036358
# 3.0             0.007544
# 1.0             0.003124
# 2.0             0.002060

# %%
percent.reset_index()
# Out:
#    driver_score  percentage
# 0           5.0    0.149518
# 1           4.0    0.055633
# 2           0.0    0.036358
# 3           3.0    0.007544
# 4           1.0    0.003124
# 5           2.0    0.002060

# %%
driver_score_counts = percent.sort_values('driver_score')

# %%
driver_score_counts.reset_index()
# Out:
#    driver_score  percentage
# 0           0.0    0.036358
# 1           1.0    0.003124
# 2           2.0    0.002060
# 3           3.0    0.007544
# 4           4.0    0.055633
# 5           5.0    0.149518

# %%
driver_score_counts.shape
# Out:
# (6, 1)

# %%
scores = taxi.driver_score.value_counts(normalize=True).mul(100).round(2)

# %%
scores = scores.reset_index()

# %%
scores
# Out:
#    driver_score  proportion
# 0           5.0       58.81
# 1           4.0       21.88
# 2           0.0       14.30
# 3           3.0        2.97
# 4           1.0        1.23
# 5           2.0        0.81

# %%
scores = scores.rename({'proportion':'percentage'})
scores
# Out:
#    driver_score  proportion
# 0           5.0       58.81
# 1           4.0       21.88
# 2           0.0       14.30
# 3           3.0        2.97
# 4           1.0        1.23
# 5           2.0        0.81

# %%
driver_score_counts = scores.sort_values('driver_score')
driver_score_counts
# Out:
#    driver_score  proportion
# 2           0.0       14.30
# 4           1.0        1.23
# 5           2.0        0.81
# 3           3.0        2.97
# 1           4.0       21.88
# 0           5.0       58.81

# %%
ax = sns.barplot(x='rider_score', y='percentage', data=, color='blue', alpha=0.5)
ax.set(xlabel='Rider score', ylabel='Percentage')
sns.despine()  # убрать часть рамки графика
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[173], line 1
# ----> 1 ax = sns.barplot(x='rider_score', y='percentage', data=taxi, color='blue', alpha=0.5)
#       2 ax.set(xlabel='Rider score', ylabel='Percentage')
#       3 sns.despine()  # убрать часть рамки графика
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
# ...

# %%
rider_scores = taxi.rider_score.value_counts(normalize=True).mul(100).round(2)
rider_scores = rider_scores.reset_index()
rider_scores = rider_scores.rename(columns={'index':'rider_score', 'rider_score':'percentage'})
rider_scores_counts = rider_scores.sort_values('rider_score')
ax = sns.barplot(x='rider_score', y='percentage', data=rider_scores_counts, color='blue', alpha=0.5)
ax.set(xlabel='Rider score', ylabel='Percentage')
sns.despine()  # убрать часть рамки графика
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/tr/xllz8_cx4rq2z22kr4zds8yc0000gn/T/ipykernel_47243/1196921891.py in ?()
#       1 rider_scores = taxi.rider_score.value_counts(normalize=True).mul(100).round(2)
#       2 rider_scores = rider_scores.reset_index()
#       3 rider_scores = rider_scores.rename(columns={'index':'rider_score', 'rider_score':'percentage'})
# ----> 4 rider_scores_counts = rider_scores.sort_values('rider_score')
#       5 ax = sns.barplot(x='rider_score', y='percentage', data=rider_scores_counts, color='blue', alpha=0.5)
#       6 ax.set(xlabel='Rider score', ylabel='Percentage')
#       7 sns.despine()  # убрать часть рамки графика
#
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6940             )
#    6941         elif len(by):
# ...
