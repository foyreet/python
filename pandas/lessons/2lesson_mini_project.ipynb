# %%
import pandas as pd

# %%
bookings = pd.read_csv('bookings.csv', sep=';')

# %%
bookings_head = bookings.head(7)

# %%
bookings_head
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# ...

# %%
bookings.shape
# Out:
# (119390, 21)

# %%
bookings.dtypes
# Out:
# Hotel                         object
# Is Canceled                    int64
# Lead Time                      int64
# arrival full date             object
# Arrival Date Year              int64
# Arrival Date Month            object
# Arrival Date Week Number       int64
# Arrival Date Day of Month      int64
# Stays in Weekend nights        int64
# Stays in week nights           int64
# stays total nights             int64
# Adults                         int64
# Children                     float64
# Babies                         int64
# Meal                          object
# Country                       object
# Reserved Room Type            object
# Assigned room type            object
# customer type                 object
# Reservation Status            object
# Reservation status_date       object
# dtype: object

# %%
bookings.head()
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
bookings.columns = bookings.columns.str.lower().str.replace(' ', '_')

# %%
bookings
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
country_bron = bookings.loc[bookings.is_canceled == 0].country.value_counts().head(5)

# %%
country_bron
# Out:
# country
# PRT    21071
# GBR     9676
# FRA     8481
# ESP     6391
# DEU     6069
# Name: count, dtype: int64

# %%
bookings.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
bookings['stays_total_nights'] = bookings['stays_in_weekend_nights'] + bookings['stays_in_week_nights']

# %%
bookings
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
if 'stays_total_nights' in bookings.columns:
    print ('YES')
else:
    print ('NO')
# Out:
# YES

# %%
stays_City_hotel = bookings.loc[bookings.hotel == 'City Hotel'].stays_total_nights.mean().round(decimals=2)

# %%
stays_City_hotel
# Out:
# 2.98

# %%
stays_Resort_hotel = bookings.loc[bookings.hotel == 'Resort Hotel'].stays_total_nights.mean().round(decimals=2)

# %%
stays_Resort_hotel
# Out:
# 4.32

# %%
stays_total_nights_hotel = bookings.groupby('hotel').stays_total_nights.mean().round(2)

# %%
stays_total_nights_hotel
# Out:
# hotel
# City Hotel      2.98
# Resort Hotel    4.32
# Name: stays_total_nights, dtype: float64

# %%
bookings.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
count_differences = bookings.loc[bookings.reserved_room_type != bookings.assigned_room_type].hotel.value_counts()

# %%
count_differences
# Out:
# hotel
# Resort Hotel    7725
# City Hotel      7192
# Name: count, dtype: int64

# %%
7725+7192
# Out:
# 14917

# %%
count_differences_2 = len(bookings.loc[bookings.reserved_room_type != bookings.assigned_room_type])

# %%
count_differences_2
# Out:
# 14917

# %%
month_2016 = bookings.loc[bookings.arrival_date_year == 2016].groupby(['arrival_date_year', 'arrival_date_month'], as_index = False)
month_2016 = month_2016.agg({'arrival_date_day_of_month':'sum'}).sort_values(by = 'arrival_date_day_of_month', ascending = False)

# %%
month_2016
# Out:
#     arrival_date_year arrival_date_month  arrival_date_day_of_month
# 10               2016            October                      99958
# 0                2016              April                      89906
# 8                2016                May                      88577
# 11               2016          September                      86235
# 7                2016              March                      82026
# 1                2016             August                      79737
# 6                2016               June                      79564
# 5                2016               July                      73657
# 3                2016           February                      62915
# 2                2016           December                      61922
# 9                2016           November                      60923
# 4                2016            January                      36851

# %%
month_2017 = bookings.loc[bookings.arrival_date_year == 2017].groupby(['arrival_date_year', 'arrival_date_month'], as_index = False)
month_2017 = month_2017.agg({'arrival_date_day_of_month':'sum'}).sort_values(by = 'arrival_date_day_of_month', ascending = False)

# %%
month_2017
# Out:
#    arrival_date_year arrival_date_month  arrival_date_day_of_month
# 7               2017                May                     100424
# 0               2017              April                      90946
# 5               2017               June                      85826
# 4               2017               July                      83963
# 6               2017              March                      77961
# 1               2017             August                      77516
# 2               2017           February                      64156
# 3               2017            January                      58709

# %%
months = bookings.groupby('arrival_date_year').arrival_date_month.agg(pd.Series.mode)

# %%
months
# Out:
# arrival_date_year
# 2015    September
# 2016      October
# 2017          May
# Name: arrival_date_month, dtype: object

# %%
bookings.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
months_canceled = bookings.loc[bookings.is_canceled == 1]
months_canceled = months_canceled.groupby('arrival_date_year').arrival_date_month.agg(pd.Series.mode)

# %%
months_canceled
# Out:
# arrival_date_year
# 2015    September
# 2016      October
# 2017          May
# Name: arrival_date_month, dtype: object

# %%
mean_max = bookings.groupby(['adults', 'children', 'babies'], as_index = False).agg({'adults':'sum', 'children':'sum', 'babies':'sum'}).mean()

# %%
mean_max
# Out:
# adults      5405.536585
# children     302.512195
# babies        23.146341
# dtype: float64

# %%
mean_max_2 = bookings[['adults', 'children', 'babies']].mean()

# %%
mean_max_2
# Out:
# adults      1.856403
# children    0.103890
# babies      0.007949
# dtype: float64

# %%
bookings['total_kids'] = bookings['children'] + bookings['babies']

# %%
bookings.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
total_kids_hotel = bookings.groupby('hotel').agg({'total_kids':'mean'}).round(2)

# %%
total_kids_hotel
# Out:
#               total_kids
# hotel
# City Hotel          0.10
# Resort Hotel        0.14

# %%
def has_kids(x):
    if (bookings.total_kids > 0):
        has_kids = True
    else:
        has_kids = False

# %%
bookings['has_kids'] = bookings.total_kids.astype(bool)

# %%
bookings[['has_kids', 'is_canceled']].value_counts() / bookings[['has_kids']].value_counts() * 100
# Out:
# has_kids  is_canceled
# False     0              62.780998
#           1              37.219002
# True      0              65.049272
#           1              34.950728
# Name: count, dtype: float64
